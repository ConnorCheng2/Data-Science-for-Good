# %%
import numpy as np
import geopandas as gpd
from matplotlib import pyplot as plt
import pandas as pd
from shapely.geometry import Point
import os

# %%
dept_num = ["Dept_11-00091", "Dept_23-00089",
            "Dept_24-00013", "Dept_24-00098",
            "Dept_35-00016", "Dept_35-00013",
            "Dept_37-00027", "Dept_37-00049",
            "Dept_49-00009", "Dept_49-00033",
            "Dept_49-00035", "Dept_49-00081"]

# %%
class Read:
    def __init__(self, data=""):
        self.data = data
        
    def __str__(self):
        return self.data
        
    def readShapefile(self):
        dept_folder = "cpe-data/" + self.data + "/"
        for folders in os.listdir(dept_folder):
            if "Shapefiles" in folders:
                police_shp_folder = folders
 
        for file in os.listdir(dept_folder + police_shp_folder):
            if ".shp" in file:
                shp_file = file
            
        police_shp_gdf = gpd.read_file(dept_folder + police_shp_folder + '/' + shp_file)
        return police_shp_gdf
    
    def readPrepCSV(self):
        dept_folder = "cpe-data/" + self.data + "/"
        for file in os.listdir(dept_folder):
            if ".csv" in file:
                preped_csv_file = file
                
        return pd.read_csv(dept_folder+preped_csv_file).iloc[1:].reset_index(drop = True)
        
    def readAgeRaceSex(self):
        
        dept_folder = "cpe-data/" + self.data + "/"
        for folders in os.listdir(dept_folder):
            if "ACS" in folders:
                 ACS_folder = folders
                
        for folders in os.listdir(dept_folder + ACS_folder):
            if "race" in folders:
                AgeRaceSex_census_folder = folders
        
        for files in os.listdir(dept_folder + ACS_folder + "/" + AgeRaceSex_census_folder):
            if "ann" in files:
                AgeRaceSex_census_file = files
                
        df = pd.read_csv(dept_folder + ACS_folder + "/" + AgeRaceSex_census_folder + "/" + AgeRaceSex_census_file)
        df.columns = df.iloc[0]
        return df.iloc[1:].reset_index(drop =True)
                
                
            
    def readEmployment(self):
        dept_folder = "cpe-data/" + self.data + "/"
        
        for folders in os.listdir(dept_folder):
            if "ACS" in folders:
                 ACS_folder = folders
                
        for folders in os.listdir(dept_folder + ACS_folder):
            if "employment" in folders:
                Employment_census_folder = folders
        
        for files in os.listdir(dept_folder + ACS_folder + "/" + Employment_census_folder):
            if "ann" in files:
                Employment_census_file = files
        
        df = pd.read_csv(dept_folder + ACS_folder + "/" + Employment_census_folder + "/" + Employment_census_file)
        df.columns = df.iloc[0]
        return df.iloc[1:].reset_index(drop =True)
    
    def readPoverty(self):
        dept_folder = "cpe-data/" + self.data + "/"
        
        for folders in os.listdir(dept_folder):
            if "ACS" in folders:
                 ACS_folder = folders
                
        for folders in os.listdir(dept_folder + ACS_folder):
            if "poverty" in folders:
                Poverty_census_folder = folders
        
        for files in os.listdir(dept_folder + ACS_folder + "/" + Poverty_census_folder):
            if "ann" in files:
                Poverty_census_file = files
                
        df = pd.read_csv(dept_folder + ACS_folder + "/" + Poverty_census_folder + "/" + Poverty_census_file)
        df.columns = df.iloc[0]
        return df.iloc[1:].reset_index(drop =True)
    
    def readEducationOver25(self):
        dept_folder = "cpe-data/" + self.data + "/"
        
        for folders in os.listdir(dept_folder):
            if "ACS" in folders:
                 ACS_folder = folders
                
        for folders in os.listdir(dept_folder + ACS_folder):
            if "over-25" in folders:
                Education_census_folder = folders
        
        for files in os.listdir(dept_folder + ACS_folder + "/" + Education_census_folder):
            if "ann" in files:
                Education_census_file = files
                
        df = pd.read_csv(dept_folder + ACS_folder + "/" + Education_census_folder + "/" + Education_census_file)
        df.columns = df.iloc[0]
        return df.iloc[1:].reset_index(drop = True)
        
    
    def readTracts(self):
        pass

# %%
# read dept file regarding different region
MA = Read(dept_num[0])
IN = Read(dept_num[1])
MN1 = Read(dept_num[2])
MN2 = Read(dept_num[3])
FL1 = Read(dept_num[4])
FL2 = Read(dept_num[5])
TX1 = Read(dept_num[6])
TX2 = Read(dept_num[7])
CA1 = Read(dept_num[8])
CA2 = Read(dept_num[9])
CA3 = Read(dept_num[10])
CA4 = Read(dept_num[11])

# %%
MA_CSV = MA.readPrepCSV()
MA_SHP = MA.readShapefile()
MA_AgeRaceSex = MA.readAgeRaceSex()
MA_Employment = MA.readEmployment()
MA_Poverty = MA.readPoverty()
MA_EducationOver25 = MA.readEducationOver25()

# %%
TX1_CSV = TX1.readPrepCSV()
TX1_SHP = TX1.readShapefile()
TX1_AgeRaceSex = TX1.readAgeRaceSex()
TX1_Employment = TX1.readEmployment()
TX1_Poverty = TX1.readPoverty()
TX1_EducationOver25 = TX1.readEducationOver25()

# %%
TX1_SHP.head()
# Out:
#         NAME  SORTORDER  BATID  JURIID       COLOR  CODE EXTERNALKE  \
# 0  CHARLIE 4        1.0  400.0    11.0  16744576.0  1282       1282
# 1   GEORGE 1        1.0  194.0    15.0  16744576.0  1298       1298
# 2   GEORGE 2        1.0  194.0    15.0  16776960.0  1297       1297
# 3      IDA 1        1.0  215.0    60.0  16744576.0  1307       1307
# 4      IDA 2        1.0  215.0    60.0  16711680.0  1304       1304
#
#   BATTALIONC   DISTRICT   SECTOR  INPUT_DATE MODIFIED_D       INPUT_BY  \
# 0       CHAR  CHARLIE 4  CHARLIE  2014-12-22       None  bmartinlimuel
# 1         G1   GEORGE 1   GEORGE  2014-12-22       None  bmartinlimuel
# 2         G1   GEORGE 2   GEORGE  2014-12-22       None  bmartinlimuel
# 3         I1      IDA 1      IDA  2014-12-22       None  bmartinlimuel
# 4         I1      IDA 2      IDA  2014-12-22       None  bmartinlimuel
#
#   MODIFIED_B   BUREAU    PATROL_ARE    AREACOMMAN    SHAPE_AREA  \
# 0       None  CENTRAL   CENTRALEAST  512-974-5900  6.657440e+08
# 1       None    NORTH          DTAC  512-974-5203  2.790690e+07
# 2       None    NORTH          DTAC  512-974-5203  9.667245e+06
# 3       None  CENTRAL  NORTHCENTRAL  512-974-5203  1.054603e+08
# 4       None  CENTRAL  NORTHCENTRAL  512-974-5203  6.245594e+07
#
#        SHAPE_LEN                                           geometry
# 0  387953.791071  POLYGON ((3160030.801874995 10110945.26125, 31...
# 1   23590.887752  POLYGON ((3117569.753749996 10072205.20874999,...
# 2   19773.819675  POLYGON ((3117394.076875001 10072195.676875, 3...
# 3   48972.544807  POLYGON ((3138058.366874993 10093095.421875, 3...
# 4   38742.443899  POLYGON ((3132516.318124995 10096385.60124999,...

# %%
TX1_CSV.head()
# Out:
#       RIN  PRIMARY_KEY INCIDENT_DATE LOCATION_DISTRICT  INCIDENT_REASON  \
# 0  156701   2015541517     2/24/2015                FR   VIEWED OFFENSE
# 1  161046  20151510003     5/31/2015                GE   VIEWED OFFENSE
# 2  161381  20151510003     5/31/2015                GE   VIEWED OFFENSE
# 3  142588   2014111929     1/11/2014                HE     TRAFFIC STOP
# 4  162084  20151720001     6/21/2015                GE  DISPATCHED CALL
#
#                          REASON_FOR_FORCE              SUBJECT_ID  \
# 0  NECESSARY TO EFFECT ARREST / DETENTION   167510327: 2015541517
# 1  NECESSARY TO EFFECT ARREST / DETENTION  459191174: 20151510003
# 2         IN CUSTODY, MAINTAINING CONTROL  459191174: 20151510003
# 3   NECESSARY TO DEFEND REPORTING OFFICER   198377769: 2014111929
# 4         TO RESTRAIN FOR SUBJECTS SAFETY  459030448: 20151720001
#
#   SUBJECT_GENDER SUBJECT_RACE SUBJECT_ROLE        ...          \
# 0              M     Hispanic          NaN        ...
# 1              M     Hispanic          NaN        ...
# 2              M     Hispanic          NaN        ...
# 3              M        Black      SUSPECT        ...
# 4              M        Black          NaN        ...
#
#                   Unnamed: 19 OFFICER_YEARS_ON_FORCE Y_COORDINATE  \
# 0  CRIMINAL INTERDICTION / K9                      3      3100341
# 1     GEORGE 300 REG I PATROL                      5      3115535
# 2     GEORGE 300 REG I PATROL                      7      3115535
# 3    HENRY 700 REG III PATROL                      4      3117503
# 4     GEORGE 400 REG I PATROL                      3      3116713
#
#   Y_COORDINATE.1 LOCATION_DISTRICT.1  \
# 0       10030899                   5
# 1       10070296                   9
# 2       10070296                   9
# 3       10057313                 NaN
# 4       10067447                   3
#
#   LOCATION_FULL_STREET_ADDRESS_OR_INTERSECTION LOCATION_CITY LOCATION_STATE  \
# 0                        9900 BLOCK S IH 35 SB        Austin             TX
# 1                                 409 E 6TH ST        Austin             TX
# 2                                 409 E 6TH ST        Austin             TX
# 3                      BURTON DR / E OLTORF ST        Austin             TX
# 4                    SAN MARCOS ST / SPENCE ST        Austin             TX
#
#   LOCATION_LATITUDE LOCATION_LONGITUDE
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
#
# [5 rows x 29 columns]

# %%
TX1_AgeRaceSex.head()
# Out:
# 0                    Id          Id2                                Geography  \
# 0  1400000US48453000101  48453000101  Census Tract 1.01, Travis County, Texas
# 1  1400000US48453000102  48453000102  Census Tract 1.02, Travis County, Texas
# 2  1400000US48453000203  48453000203  Census Tract 2.03, Travis County, Texas
# 3  1400000US48453000204  48453000204  Census Tract 2.04, Travis County, Texas
# 4  1400000US48453000205  48453000205  Census Tract 2.05, Travis County, Texas
#
# 0 Estimate; SEX AND AGE - Total population  \
# 0                                     4061
# 1                                     2556
# 2                                     1460
# 3                                     3092
# 4                                     4154
#
# 0 Margin of Error; SEX AND AGE - Total population  \
# 0                                             288
# 1                                             195
# 2                                             166
# 3                                             213
# 4                                             474
#
# 0 Percent; SEX AND AGE - Total population  \
# 0                                    4061
# 1                                    2556
# 2                                    1460
# 3                                    3092
# 4                                    4154
#
# 0 Percent Margin of Error; SEX AND AGE - Total population  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# 0 Estimate; SEX AND AGE - Total population - Male  \
# 0                                            1889
# 1                                            1176
# 2                                             608
# 3                                            1567
# 4                                            2473
#
# 0 Margin of Error; SEX AND AGE - Total population - Male  \
# 0                                                237
# 1                                                157
# 2                                                 93
# 3                                                156
# 4                                                468
#
# 0 Percent; SEX AND AGE - Total population - Male  \
# 0                                           46.5
# 1                                           46.0
# 2                                           41.6
# 3                                           50.7
# 4                                           59.5
#
# 0                                                ...                                                  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
# 0 Percent; CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population  \
# 0                                               3284
# 1                                               1966
# 2                                               1143
# 3                                               2533
# 4                                               3305
#
# 0 Percent Margin of Error; CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# 0 Estimate; CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population - Male  \
# 0                                               1469
# 1                                                946
# 2                                                467
# 3                                               1337
# 4                                               2023
#
# 0 Margin of Error; CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population - Male  \
# 0                                                203
# 1                                                127
# 2                                                 88
# 3                                                160
# 4                                                404
#
# 0 Percent; CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population - Male  \
# 0                                               44.7
# 1                                               48.1
# 2                                               40.9
# 3                                               52.8
# 4                                               61.2
#
# 0 Percent Margin of Error; CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population - Male  \
# 0                                                3.7
# 1                                                5.1
# 2                                                5.9
# 3                                                5.8
# 4                                                6.1
#
# 0 Estimate; CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population - Female  \
# 0                                               1815
# 1                                               1020
# 2                                                676
# 3                                               1196
# 4                                               1282
#
# 0 Margin of Error; CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population - Female  \
# 0                                                141
# 1                                                122
# 2                                                120
# 3                                                203
# 4                                                163
#
# 0 Percent; CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population - Female  \
# 0                                               55.3
# 1                                               51.9
# 2                                               59.1
# 3                                               47.2
# 4                                               38.8
#
# 0 Percent Margin of Error; CITIZEN, VOTING AGE POPULATION - Citizen, 18 and over population - Female
# 0                                                3.7
# 1                                                5.1
# 2                                                5.9
# 3                                                5.8
# 4                                                6.1
#
# [5 rows x 339 columns]

# %%
TX1_Employment.head()
# Out:
# 0                    Id          Id2                                Geography  \
# 0  1400000US48453000101  48453000101  Census Tract 1.01, Travis County, Texas
# 1  1400000US48453000102  48453000102  Census Tract 1.02, Travis County, Texas
# 2  1400000US48453000203  48453000203  Census Tract 2.03, Travis County, Texas
# 3  1400000US48453000204  48453000204  Census Tract 2.04, Travis County, Texas
# 4  1400000US48453000205  48453000205  Census Tract 2.05, Travis County, Texas
#
# 0 Total; Estimate; Population 16 years and over  \
# 0                                          3387
# 1                                          2069
# 2                                          1279
# 3                                          2720
# 4                                          3666
#
# 0 Total; Margin of Error; Population 16 years and over  \
# 0                                                265
# 1                                                155
# 2                                                152
# 3                                                202
# 4                                                422
#
# 0 Labor Force Participation Rate; Estimate; Population 16 years and over  \
# 0                                               72.5
# 1                                               63.6
# 2                                               59.3
# 3                                               71.2
# 4                                               78.7
#
# 0 Labor Force Participation Rate; Margin of Error; Population 16 years and over  \
# 0                                                4.2
# 1                                                5.2
# 2                                                6.2
# 3                                                5.2
# 4                                                6.1
#
# 0 Employment/Population Ratio; Estimate; Population 16 years and over  \
# 0                                               67.3
# 1                                               60.7
# 2                                               53.7
# 3                                               68.1
# 4                                               73.6
#
# 0 Employment/Population Ratio; Margin of Error; Population 16 years and over  \
# 0                                                4.6
# 1                                                5.4
# 2                                                7.0
# 3                                                5.6
# 4                                                6.9
#
# 0 Unemployment rate; Estimate; Population 16 years and over  \
# 0                                                6.4
# 1                                                2.3
# 2                                                9.5
# 3                                                4.3
# 4                                                6.2
#
# 0                                                         ...                                                           \
# 0                                                         ...
# 1                                                         ...
# 2                                                         ...
# 3                                                         ...
# 4                                                         ...
#
# 0 Unemployment rate; Estimate; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Some college or associate's degree  \
# 0                                                0.0
# 1                                                1.6
# 2                                                0.0
# 3                                                0.8
# 4                                                0.0
#
# 0 Unemployment rate; Margin of Error; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Some college or associate's degree  \
# 0                                               10.9
# 1                                                5.0
# 2                                               36.4
# 3                                                1.6
# 4                                               14.2
#
# 0 Total; Estimate; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher  \
# 0                                               1781
# 1                                               1101
# 2                                                537
# 3                                               1411
# 4                                               2062
#
# 0 Total; Margin of Error; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher  \
# 0                                                206
# 1                                                125
# 2                                                109
# 3                                                140
# 4                                                267
#
# 0 Labor Force Participation Rate; Estimate; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher  \
# 0                                               92.1
# 1                                               85.4
# 2                                               80.8
# 3                                               90.9
# 4                                               95.1
#
# 0 Labor Force Participation Rate; Margin of Error; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher  \
# 0                                                3.7
# 1                                                5.5
# 2                                                7.4
# 3                                                3.7
# 4                                                4.2
#
# 0 Employment/Population Ratio; Estimate; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher  \
# 0                                               85.2
# 1                                               84.1
# 2                                               76.4
# 3                                               89.2
# 4                                               92.8
#
# 0 Employment/Population Ratio; Margin of Error; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher  \
# 0                                                5.0
# 1                                                6.2
# 2                                                7.5
# 3                                                4.2
# 4                                                5.4
#
# 0 Unemployment rate; Estimate; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher  \
# 0                                                7.0
# 1                                                1.5
# 2                                                5.5
# 3                                                1.9
# 4                                                2.4
#
# 0 Unemployment rate; Margin of Error; EDUCATIONAL ATTAINMENT - Population 25 to 64 years - Bachelor's degree or higher
# 0                                                5.3
# 1                                                2.1
# 2                                                4.7
# 3                                                1.8
# 4                                                3.9
#
# [5 rows x 283 columns]

# %%
TX1_Poverty.head()
# Out:
# 0                    Id          Id2                                Geography  \
# 0  1400000US48453000101  48453000101  Census Tract 1.01, Travis County, Texas
# 1  1400000US48453000102  48453000102  Census Tract 1.02, Travis County, Texas
# 2  1400000US48453000203  48453000203  Census Tract 2.03, Travis County, Texas
# 3  1400000US48453000204  48453000204  Census Tract 2.04, Travis County, Texas
# 4  1400000US48453000205  48453000205  Census Tract 2.05, Travis County, Texas
#
# 0 Total; Estimate; Population for whom poverty status is determined  \
# 0                                               3988
# 1                                               2525
# 2                                               1268
# 3                                               3045
# 4                                               4154
#
# 0 Total; Margin of Error; Population for whom poverty status is determined  \
# 0                                                273
# 1                                                182
# 2                                                159
# 3                                                201
# 4                                                474
#
# 0 Below poverty level; Estimate; Population for whom poverty status is determined  \
# 0                                                267
# 1                                                 80
# 2                                                417
# 3                                                579
# 4                                                583
#
# 0 Below poverty level; Margin of Error; Population for whom poverty status is determined  \
# 0                                                101
# 1                                                 72
# 2                                                129
# 3                                                179
# 4                                                385
#
# 0 Percent below poverty level; Estimate; Population for whom poverty status is determined  \
# 0                                                6.7
# 1                                                3.2
# 2                                               32.9
# 3                                               19.0
# 4                                               14.0
#
# 0 Percent below poverty level; Margin of Error; Population for whom poverty status is determined  \
# 0                                                2.6
# 1                                                2.8
# 2                                                9.3
# 3                                                5.4
# 4                                                8.5
#
# 0 Total; Estimate; AGE - Under 18 years  \
# 0                                   734
# 1                                   558
# 2                                   106
# 3                                   406
# 4                                   544
#
# 0                            ...                              \
# 0                            ...
# 1                            ...
# 2                            ...
# 3                            ...
# 4                            ...
#
# 0 Below poverty level; Estimate; Worked less than full-time, year-round in the past 12 months  \
# 0                                                122
# 1                                                  5
# 2                                                199
# 3                                                291
# 4                                                311
#
# 0 Below poverty level; Margin of Error; Worked less than full-time, year-round in the past 12 months  \
# 0                                                 69
# 1                                                  7
# 2                                                 81
# 3                                                145
# 4                                                260
#
# 0 Percent below poverty level; Estimate; Worked less than full-time, year-round in the past 12 months  \
# 0                                               27.7
# 1                                                3.4
# 2                                               53.5
# 3                                               51.6
# 4                                               40.3
#
# 0 Percent below poverty level; Margin of Error; Worked less than full-time, year-round in the past 12 months  \
# 0                                               16.0
# 1                                                5.0
# 2                                               13.7
# 3                                               17.4
# 4                                               23.6
#
# 0 Total; Estimate; Did not work Total; Margin of Error; Did not work  \
# 0                           454                                  106
# 1                           251                                   82
# 2                           155                                   78
# 3                           257                                  107
# 4                           310                                  184
#
# 0 Below poverty level; Estimate; Did not work  \
# 0                                         120
# 1                                          32
# 2                                         109
# 3                                         213
# 4                                         224
#
# 0 Below poverty level; Margin of Error; Did not work  \
# 0                                                 82
# 1                                                 24
# 2                                                 63
# 3                                                104
# 4                                                162
#
# 0 Percent below poverty level; Estimate; Did not work  \
# 0                                               26.4
# 1                                               12.7
# 2                                               70.3
# 3                                               82.9
# 4                                               72.3
#
# 0 Percent below poverty level; Margin of Error; Did not work
# 0                                               15.1
# 1                                                9.5
# 2                                               15.6
# 3                                               11.6
# 4                                               23.1
#
# [5 rows x 369 columns]

# %%
TX1_EducationOver25.head()
# Out:
# 0                    Id          Id2                                Geography  \
# 0  1400000US48453000101  48453000101  Census Tract 1.01, Travis County, Texas
# 1  1400000US48453000102  48453000102  Census Tract 1.02, Travis County, Texas
# 2  1400000US48453000203  48453000203  Census Tract 2.03, Travis County, Texas
# 3  1400000US48453000204  48453000204  Census Tract 2.04, Travis County, Texas
# 4  1400000US48453000205  48453000205  Census Tract 2.05, Travis County, Texas
#
# 0 Estimate; Total: Margin of Error; Total:  \
# 0             3031                     257
# 1             1887                     147
# 2              761                     137
# 3             2122                     182
# 4             3154                     337
#
# 0 Estimate; Total: - No schooling completed  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
#
# 0 Margin of Error; Total: - No schooling completed  \
# 0                                               13
# 1                                               13
# 2                                               13
# 3                                               13
# 4                                               13
#
# 0 Estimate; Total: - Nursery school Margin of Error; Total: - Nursery school  \
# 0                                 0                                       13
# 1                                 0                                       13
# 2                                 0                                       13
# 3                                 0                                       13
# 4                                 0                                       13
#
# 0 Estimate; Total: - Kindergarten                    ...                      \
# 0                               0                    ...
# 1                               0                    ...
# 2                               0                    ...
# 3                               0                    ...
# 4                               0                    ...
#
# 0 Estimate; Total: - Associate's degree  \
# 0                                   109
# 1                                    32
# 2                                    18
# 3                                    48
# 4                                    98
#
# 0 Margin of Error; Total: - Associate's degree  \
# 0                                           68
# 1                                           28
# 2                                           19
# 3                                           44
# 4                                           94
#
# 0 Estimate; Total: - Bachelor's degree  \
# 0                                 1178
# 1                                  739
# 2                                  294
# 3                                  870
# 4                                 1122
#
# 0 Margin of Error; Total: - Bachelor's degree  \
# 0                                         178
# 1                                         127
# 2                                          88
# 3                                         141
# 4                                         222
#
# 0 Estimate; Total: - Master's degree  \
# 0                                660
# 1                                406
# 2                                194
# 3                                457
# 4                                757
#
# 0 Margin of Error; Total: - Master's degree  \
# 0                                       147
# 1                                        94
# 2                                        71
# 3                                       107
# 4                                       198
#
# 0 Estimate; Total: - Professional school degree  \
# 0                                           241
# 1                                           217
# 2                                            31
# 3                                            70
# 4                                            99
#
# 0 Margin of Error; Total: - Professional school degree  \
# 0                                                 85
# 1                                                 78
# 2                                                 23
# 3                                                 44
# 4                                                 74
#
# 0 Estimate; Total: - Doctorate degree  \
# 0                                 178
# 1                                 193
# 2                                  62
# 3                                 155
# 4                                 171
#
# 0 Margin of Error; Total: - Doctorate degree
# 0                                         84
# 1                                         68
# 2                                         37
# 3                                         48
# 4                                        111
#
# [5 rows x 53 columns]
